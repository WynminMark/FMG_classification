# %%
'''
用于调试代码
'''
import logging

from logger import logger_init
from FMG_P import *

# 初始化logger
logger_init(log_level=logging.CRITICAL)

# %%
# 记录鼻导管压力测试实验中，各路信号所对应的板子通道号与传感器编号
ch_sensor_df = pd.DataFrame({"ch_num":[1,2,3,4,5], "sensor_num":[20,10,'s1',24,20]})
ch_sensor_df
# Out:
#    ch_num sensor_num
# 0       1         20
# 1       2         10
# 2       3         s1
# 3       4         24
# 4       5         20

# %%
'''
初始化class并处理FMG数据获得校准曲线
'''
"""ch1"""
folder_path = r"E:\Data\WearabelLabBugDataset\7mm_s1+s2"
# 输入校准数据的路径，通道数
sensor1 = FMG2pressure(1, 0, ex1 = [folder_path + "\\" + "1-1.db", folder_path + "\\" + "1-1.txt"],
                             ex2 = [folder_path + "\\" + "1-2.db", folder_path + "\\" + "1-2.txt"],
                             ex3 = [folder_path + "\\" + "1-3.db", folder_path + "\\" + "1-3.txt"])
# 显示校准测试的结果，获得多项式拟合曲线
sensor1.get_fit_curve()

# %%
'''
初始化class并处理FMG数据获得校准曲线
'''
folder_path = r"E:\Data\WearabelLabBugDataset\7mm_s1+s2"
# 输入校准数据的路径，通道数
sensor2 = FMG2pressure(1, 0, ex1 = [folder_path + "\\" + "2-1.db", folder_path + "\\" + "2-1.txt"],
                             ex2 = [folder_path + "\\" + "2-2.db", folder_path + "\\" + "2-2.txt"],
                             ex3 = [folder_path + "\\" + "2-3.db", folder_path + "\\" + "2-3.txt"])
# 显示校准测试的结果，获得多项式拟合曲线
sensor2.get_fit_curve()

# %%
'''
初始化class并处理FMG数据获得校准曲线
'''
"""ch1"""
# 输入校准数据的路径，通道数
sensor22 = FMG2pressure(1, 0, ex1 = [r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230327传感器校准数据\22-1.db", r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230327传感器校准数据\22-1.txt"],
                             ex2 = [r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230327传感器校准数据\22-2.db", r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230327传感器校准数据\22-2.txt"],
                             ex3 = [r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230327传感器校准数据\22-3.db", r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230327传感器校准数据\22-3.txt"])
# 显示校准测试的结果，获得多项式拟合曲线
sensor22.get_fit_curve()

# %%
"""ch2"""
# 输入校准数据的路径，通道数
sensor10 = FMG2pressure(1, 0, ex1 = [r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230326传感器校准数据\10-1.db", r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230326传感器校准数据\10-1.txt"],
                             ex2 = [r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230326传感器校准数据\10-2.db", r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230326传感器校准数据\10-2.txt"],
                             ex3 = [r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230326传感器校准数据\10-3.db", r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230326传感器校准数据\10-3.txt"])
# 显示校准测试的结果和多项式拟合曲线
sensor10.get_fit_curve()

# %%
"""ch3"""
# 输入校准数据的路径，通道数
sensors1 = FMG2pressure(1, 0, ex1 = [r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230327传感器校准数据\s1-1.db", r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230327传感器校准数据\s1-1.txt"],
                             ex2 = [r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230327传感器校准数据\s1-2.db", r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230327传感器校准数据\s1-2.txt"],
                             ex3 = [r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230327传感器校准数据\s1-3.db", r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230327传感器校准数据\s1-3.txt"])
# 显示校准测试的结果和多项式拟合曲线
sensors1.get_fit_curve()

# %%
"""ch4"""
# 输入校准数据的路径，通道数
sensor24 = FMG2pressure(1, 0, ex1 = [r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230327传感器校准数据\24-1.db", r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230327传感器校准数据\24-1.txt"],
                             ex2 = [r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230327传感器校准数据\24-2.db", r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230327传感器校准数据\24-2.txt"],
                             ex3 = [r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230327传感器校准数据\24-3.db", r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230327传感器校准数据\24-3.txt"])
# 显示校准测试的结果和多项式拟合曲线
sensor24.get_fit_curve()

# %%
"""ch5"""
# 输入校准数据的路径，通道数
sensor20 = FMG2pressure(1, 0, ex1 = [r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230326传感器校准数据\20-1.db", r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230326传感器校准数据\20-1.txt"],
                             ex2 = [r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230326传感器校准数据\20-2.db", r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230326传感器校准数据\20-2.txt"],
                             ex3 = [r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230326传感器校准数据\20-3.db", r"D:\LEARNINNNNNNNNNNNNG\ExperimentData\20230326传感器校准数据\20-3.txt"])
# 显示校准测试的结果和多项式拟合曲线
sensor20.get_fit_curve()

# %%
'''
处理实验中的FMG输出数据，获得压力值
'''
# 输入实验数据的路径，获得一次实验中的5channel数据
raw_FMG = pd.read_table(r"E:\Data\20230410-yian\shiyan\标准\yongsheng-jujue.db",  sep = ';', header = None)
# 输入与传感器编号对应的数据通道
ch1 = sensor22.fit_equation(raw_FMG[1].values)
ch2 = sensor10.fit_equation(raw_FMG[2].values)
ch3 = sensors1.fit_equation(raw_FMG[3].values)
ch4 = sensor24.fit_equation(raw_FMG[4].values)
ch5 = sensor20.fit_equation(raw_FMG[5].values)

# 转换成压力的数据存到df里方便可视化和保存
final_df = pd.DataFrame({"ch1": ch1, "ch2": ch2, "ch3": ch3, "ch4": ch4, "ch5": ch5})
final_df.plot(y=["ch1", "ch2", "ch3", "ch4",  "ch5"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\code\wearable_lab\process_FMG.ipynb Cell 10 line 8
#       <a href='vscode-notebook-cell:/e%3A/code/wearable_lab/process_FMG.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a> # 输入与传感器编号对应的数据通道
#       <a href='vscode-notebook-cell:/e%3A/code/wearable_lab/process_FMG.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a> ch1 = sensor22.fit_equation(raw_FMG[1].values)
# ----> <a href='vscode-notebook-cell:/e%3A/code/wearable_lab/process_FMG.ipynb#X11sZmlsZQ%3D%3D?line=7'>8</a> ch2 = sensor10.fit_equation(raw_FMG[2].values)
#       <a href='vscode-notebook-cell:/e%3A/code/wearable_lab/process_FMG.ipynb#X11sZmlsZQ%3D%3D?line=8'>9</a> ch3 = sensors1.fit_equation(raw_FMG[3].values)
#      <a href='vscode-notebook-cell:/e%3A/code/wearable_lab/process_FMG.ipynb#X11sZmlsZQ%3D%3D?line=9'>10</a> ch4 = sensor24.fit_equation(raw_FMG[4].values)
#
# ...

# %%
sensor10.get_pressure_unit()
# 保存成csv
# final_df.to_csv()
# Out:
# 'cmH2O'

# %%
"""
基于curve_fit方法拟合平板变形理论方程中的参数
效果不好
"""
'''
import pylab
from scipy.optimize import curve_fit

popt, pcov = curve_fit(plate_func, P1[0 : max_FMG_index], FMG[0 : max_FMG_index])
y_pred = [plate_func(i, popt[0], popt[1], popt[2], popt[3], popt[4], popt[5]) for i in P1[0 : max_FMG_index]]
print(popt)

plot1 = pylab.plot(P1[0 : max_FMG_index], FMG[0 : max_FMG_index], '*', label = 'original')
plot2 = pylab.plot(P1[0 : max_FMG_index], y_pred, 'r', label = 'fit curve')
pylab.show()
'''
# Out:
# "\nimport pylab\nfrom scipy.optimize import curve_fit\n\npopt, pcov = curve_fit(plate_func, P1[0 : max_FMG_index], FMG[0 : max_FMG_index])\ny_pred = [plate_func(i, popt[0], popt[1], popt[2], popt[3], popt[4], popt[5]) for i in P1[0 : max_FMG_index]]\nprint(popt)\n\nplot1 = pylab.plot(P1[0 : max_FMG_index], FMG[0 : max_FMG_index], '*', label = 'original')\nplot2 = pylab.plot(P1[0 : max_FMG_index], y_pred, 'r', label = 'fit curve')\npylab.show()\n"
